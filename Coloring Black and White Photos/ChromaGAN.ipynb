# %%
# !rm -rf '/content/dataset'

# %%
import shutil
drive_dir='/content/drive/My Drive/Colab Notebooks/GAN/'
# shutil.unpack_archive(drive_dir+'celeb_1.tar', '/content/dataset/train', 'tar')
# shutil.unpack_archive(drive_dir+'celeb_1.tar', '/content/dataset/test', 'tar')

# %%
# !pip install tensorflow==1.12.0
# !pip install keras==2.2.4
# opencv-python==4.1.0
# numpy==1.15.4

# %%
cd '/content/drive/My Drive/Colab Notebooks/GAN/ChromaGAN'
# Out:
# /content/drive/My Drive/Colab Notebooks/GAN/ChromaGAN

# %%
# !python train.py
